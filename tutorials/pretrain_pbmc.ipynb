# %% [markdown]
#  # (Continue) Pretraining a GET Model on PBMC 10k ATAC
#
#
#  This tutorial demonstrates how to train a GET model to predict ATAC-seq peaks using motif information. We'll cover:
#
#  1. Loading and configuring the model
#
#  2. Training without a pretrained checkpoint
#
#  3. Training with a pretrained checkpoint
#
#  4. Comparing the results
#
#
#
#  ## Setup
#
#  First, let's import the necessary modules and set up our configuration.
#
#  Note:
#  If you run from a Mac, make sure you use the jupyter notebook rather than the VSCode interactive python editor as the later seems to have issue with multiple workers.
#  If you run from Linux, both should work fine.

# %%
#%%
from get_model.config.config import load_config, pretty_print_config
from get_model.run_region import run_zarr as run

# %% [markdown]
#  ## Configuration
#
#
#
#  We'll start by loading a predefined configuration and customizing it for our needs.
#
#  The base configuration is in `get_model/config/finetune_tutorial.yaml`

# %%
celltype_for_modeling = ['cd4_naive', 'cd8_naive', 'cd4_tcm', 'cd14_mono']
cfg = load_config('finetune_tutorial') # load the predefined finetune tutorial config
cfg.run.project_name = 'pretrain_pbmc' # this is a unique name for this project
cfg.dataset.zarr_path = "./pbmc10k_multiome.zarr" # the tutorial data which contains astrocyte atac & rna
cfg.dataset.celltypes = ','.join(celltype_for_modeling) # the celltypes you want to pretrain
cfg.dataset.leave_out_chromosomes = None # pretrain on all chromosomes
cfg.run.use_wandb=True # this is a logging system, you can turn it off by setting it to False
cfg.training.epochs = 50 # this is the number of epochs you want to train for
cfg.training.val_check_interval = 1.0 # validation check every epochs; this is for mac because the evaluation step is slow on it somehow...

# %% [markdown]
#  ### Model Selection
#
#
#  We'll use the GETRegionPretrain model, which is designed to use contextual motif(+atac) information to target motif(+atac) information
#
#  This model is particularly useful for understanding the relationship between motifs and chromatin accessibility.

# %%
#%%
# Switch model to finetune ATAC model
cfg.model = load_config('model/GETRegionPretrain').model.model
cfg.dataset.mask_ratio = 0.5 # mask 50% of the motifs. This has to be set for pretrain dataloader to generate proper mask

# %% [markdown]
#  ## Training Without Pretraining Checkpoint
#
#
#
#  First, let's train the model from scratch (without using a pretrained checkpoint).
#
#  This will give us a baseline for comparison.

# %%
#%%
# first run the model without initializing with a pretrain checkpoint
cfg.run.run_name='pretrain_pbmc_scratch' # this is a unique name for this run
cfg.finetune.checkpoint = None
cfg.finetune.use_lora = False
trainer = run(cfg)
# Out:
# wandb version 0.19.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.4
# Run data is saved locally in <code>/home/xf2217/output/pretrain_pbmc/pretrain_pbmc_scratch/wandb/run-20250103_235047-0wtrdc3e</code>
# Syncing run <strong><a href='https://wandb.ai/get-v3/pretrain_pbmc/runs/0wtrdc3e' target="_blank">pretrain_pbmc_scratch</a></strong> to <a href='https://wandb.ai/get-v3/pretrain_pbmc' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/get-v3/pretrain_pbmc' target="_blank">https://wandb.ai/get-v3/pretrain_pbmc</a>
#  View run at <a href='https://wandb.ai/get-v3/pretrain_pbmc/runs/0wtrdc3e' target="_blank">https://wandb.ai/get-v3/pretrain_pbmc/runs/0wtrdc3e</a>
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# 100%|██████████| 4/4 [00:00<00:00,  5.58it/s]
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# 100%|██████████| 4/4 [00:00<00:00,  5.53it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:652: Checkpoint directory /home/xf2217/output/pretrain_pbmc/pretrain_pbmc_scratch/checkpoints exists and is not empty.
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>masked_mse</td><td>█▄▃▄▂▂▃▃▃▃▄▃▄▄▄█▄▃▄▄▆▃▃▃▃▃▃▄▃▃▂▃▂▂▃▄▃▁▃▂</td></tr><tr><td>masked_pearson</td><td>▁▃▅▄▆▇▇▆▅▅▅▆▆▅▅▁▅▅▄▃▅▅▇▅▆▆▆▅▆▇▇▆▇▇▆▆▆█▅█</td></tr><tr><td>masked_r2</td><td>▁▅▇▆▇▇▆▇▆▇▇▆▆▆▅▁▆▆▅▄▃▆▆▆▆▆▆▆▇▇▇▆▇▇▆▇▇█▇▇</td></tr><tr><td>train_loss</td><td>█▅▅▂▁▃▃▆▄▄▂▃▅▂▂▂▂▂▄▂▄▃▄▂▅▁▃▂▄▃▄▁▁▁▃▂▂▅▂▃</td></tr><tr><td>train_masked_loss</td><td>█▅▅▂▁▃▃▆▄▄▂▃▅▂▂▂▂▂▄▂▄▃▄▂▅▁▃▂▄▃▄▁▁▁▃▂▂▅▂▃</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>val_loss</td><td>█▄▃▄▂▂▃▃▃▃▄▃▄▄▄█▄▃▄▄▆▃▃▃▃▃▃▄▃▃▂▃▂▂▃▄▃▁▃▂</td></tr><tr><td>val_masked_loss</td><td>█▄▃▄▂▂▃▃▃▃▄▃▄▄▄█▄▃▄▄▆▃▃▃▃▃▃▄▃▃▂▃▂▂▃▄▃▁▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>49</td></tr><tr><td>masked_mse</td><td>0.00153</td></tr><tr><td>masked_pearson</td><td>0.23068</td></tr><tr><td>masked_r2</td><td>0.04417</td></tr><tr><td>train_loss</td><td>0.00119</td></tr><tr><td>train_masked_loss</td><td>0.00119</td></tr><tr><td>trainer/global_step</td><td>12899</td></tr><tr><td>val_loss</td><td>0.00153</td></tr><tr><td>val_masked_loss</td><td>0.00153</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pretrain_pbmc_scratch</strong> at: <a href='https://wandb.ai/get-v3/pretrain_pbmc/runs/0wtrdc3e' target="_blank">https://wandb.ai/get-v3/pretrain_pbmc/runs/0wtrdc3e</a><br/>Synced 6 W&B file(s), 51 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/home/xf2217/output/pretrain_pbmc/pretrain_pbmc_scratch/wandb/run-20250103_235047-0wtrdc3e/logs</code>

# %%
#%%
trainer.callback_metrics
# Out:
# {'train_masked_loss': tensor(0.0012),
#  'train_loss': tensor(0.0012),
#  'val_masked_loss': tensor(0.0015),
#  'masked_pearson': tensor(0.2307),
#  'masked_mse': tensor(0.0015),
#  'masked_r2': tensor(0.0442),
#  'val_loss': tensor(0.0015)}

# %% [markdown]
#  ## Continue Training With Pretrained Checkpoint Using LoRA
#
#
#
#  Now, let's train the model using a pretrained checkpoint. This checkpoint was trained on a large dataset
#
#  and should help the model learn faster and potentially achieve better performance.
#
#
#
#  Note: You'll need to download the checkpoint first:
#
#  ```bash
#
#  aws s3 cp s3://2023-get-xf2217/get_demo/checkpoints/regulatory_inference_checkpoint_fetal_adult/pretrain_fetal_adult/checkpoint-799.pth ./checkpoint-799.pth
#
#  ```

# %%
#%%
# now train the model with a pretrain checkpoint
cfg.finetune.checkpoint = './checkpoint-799.pth'
cfg.run.run_name = 'pretrain_pbmc_from_pretrain_lora'
cfg.finetune.model_key = "model"
cfg.finetune.rename_config = {
  "encoder.head.": "head_mask.",
  "encoder.region_embed": "region_embed",
  "region_embed.proj.": "region_embed.embed.",
  "encoder.cls_token": "cls_token",
}
cfg.finetune.strict = True
cfg.finetune.use_lora = True
cfg.finetune.layers_with_lora = ['region_embed', 'encoder']
trainer = run(cfg)
trainer.callback_metrics
# Out:
# Load ckpt from ./checkpoint-799.pth
# Load state_dict by model_key = model
# wandb version 0.19.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.4
# Run data is saved locally in <code>/home/xf2217/output/pretrain_pbmc/pretrain_pbmc_from_pretrain_lora/wandb/run-20250104_003721-z9ri42qi</code>
# Syncing run <strong><a href='https://wandb.ai/get-v3/pretrain_pbmc/runs/z9ri42qi' target="_blank">pretrain_pbmc_from_pretrain_lora</a></strong> to <a href='https://wandb.ai/get-v3/pretrain_pbmc' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/get-v3/pretrain_pbmc' target="_blank">https://wandb.ai/get-v3/pretrain_pbmc</a>
#  View run at <a href='https://wandb.ai/get-v3/pretrain_pbmc/runs/z9ri42qi' target="_blank">https://wandb.ai/get-v3/pretrain_pbmc/runs/z9ri42qi</a>
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# 100%|██████████| 4/4 [00:00<00:00,  5.49it/s]
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# 100%|██████████| 4/4 [00:00<00:00,  5.53it/s]
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='36.021 MB of 36.021 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>masked_mse</td><td>▅▄▅█▄▅▄▄▄▃▃▃▅▄▃▃▃█▃▄▅▃▃▇▂▁▃▃▂▃▃▁▃▂▆▂▃▂▃▃</td></tr><tr><td>masked_pearson</td><td>▅▅▄▁▆▄▆▆▇▇▇▇▅▇▇▇▇▂▇▇▅██▃█▇▆██▇███▇▄▇████</td></tr><tr><td>masked_r2</td><td>▅▆▅▂▆▄▇▆▇▆▇▇▅▇██▇▁▇█▆▇█▃▇▇▆██▇███▇▅▇████</td></tr><tr><td>train_loss</td><td>▅▄▃▄▄▃▅▃▇▃▆▃▄▂▁▁▂▃▂▃▃▅▂▆▂▃▅▃▃▄▂█▄▂▃▁▅▆▄▁</td></tr><tr><td>train_masked_loss</td><td>▅▄▃▄▄▃▅▃▇▃▆▃▄▂▁▁▂▃▂▃▃▅▂▆▂▃▅▃▃▄▂█▄▂▃▁▅▆▄▁</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>val_loss</td><td>▅▄▅█▄▅▄▄▄▃▃▃▅▄▃▃▃█▃▄▅▃▃▇▂▁▃▃▂▃▃▁▃▂▆▂▃▂▃▃</td></tr><tr><td>val_masked_loss</td><td>▅▄▅█▄▅▄▄▄▃▃▃▅▄▃▃▃█▃▄▅▃▃▇▂▁▃▃▂▃▃▁▃▂▆▂▃▂▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>49</td></tr><tr><td>masked_mse</td><td>0.0015</td></tr><tr><td>masked_pearson</td><td>0.25941</td></tr><tr><td>masked_r2</td><td>0.06681</td></tr><tr><td>train_loss</td><td>0.00123</td></tr><tr><td>train_masked_loss</td><td>0.00123</td></tr><tr><td>trainer/global_step</td><td>12899</td></tr><tr><td>val_loss</td><td>0.0015</td></tr><tr><td>val_masked_loss</td><td>0.0015</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pretrain_pbmc_from_pretrain_lora</strong> at: <a href='https://wandb.ai/get-v3/pretrain_pbmc/runs/z9ri42qi' target="_blank">https://wandb.ai/get-v3/pretrain_pbmc/runs/z9ri42qi</a><br/>Synced 6 W&B file(s), 51 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/home/xf2217/output/pretrain_pbmc/pretrain_pbmc_from_pretrain_lora/wandb/run-20250104_003721-z9ri42qi/logs</code>
# {'train_masked_loss': tensor(0.0012),
#  'train_loss': tensor(0.0012),
#  'val_masked_loss': tensor(0.0015),
#  'masked_pearson': tensor(0.2594),
#  'masked_mse': tensor(0.0015),
#  'masked_r2': tensor(0.0668),
#  'val_loss': tensor(0.0015)}

# %%
#%%
# now train the model with a pretrain checkpoint without using LoRA
cfg.finetune.checkpoint = './checkpoint-799.pth'
cfg.run.run_name = 'pretrain_pbmc_from_pretrain_no_lora'
cfg.finetune.use_lora = False
trainer = run(cfg)
trainer.callback_metrics
# Out:
# Load ckpt from ./checkpoint-799.pth
# Load state_dict by model_key = model
# Tracking run with wandb version 0.15.4
# Run data is saved locally in <code>/home/xf2217/output/pretrain_pbmc/pretrain_pbmc_from_pretrain_no_lora/wandb/run-20250104_010514-od1xfypw</code>
# Syncing run <strong><a href='https://wandb.ai/get-v3/pretrain_pbmc/runs/od1xfypw' target="_blank">pretrain_pbmc_from_pretrain_no_lora</a></strong> to <a href='https://wandb.ai/get-v3/pretrain_pbmc' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/get-v3/pretrain_pbmc' target="_blank">https://wandb.ai/get-v3/pretrain_pbmc</a>
#  View run at <a href='https://wandb.ai/get-v3/pretrain_pbmc/runs/od1xfypw' target="_blank">https://wandb.ai/get-v3/pretrain_pbmc/runs/od1xfypw</a>
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# 100%|██████████| 4/4 [00:00<00:00,  5.42it/s]
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# Leave out chromosomes: []
# Input chromosomes: ['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22', 'chrX']
# 100%|██████████| 4/4 [00:00<00:00,  5.45it/s]
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Validation: |          | 0/? [00:00<?, ?it/s]
# /home/xf2217/mambaforge-pypy3/envs/get_started/lib/python3.10/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>masked_mse</td><td>█▅▄▄▄▆▃▄▃▄█▂▅▆▃█▂▃▃▃▃▄▄▃▄▃▂▁▄▂▃▂▂▂▃▂▄▂▃▃</td></tr><tr><td>masked_pearson</td><td>▂▄▅▅▆▄▇▇▆▅▁▇▆▄▇▁▇▇▇▆▇▇▄▇▆███▇▇██████▆███</td></tr><tr><td>masked_r2</td><td>▂▅▆▅▇▂▇▇▇▆▁▇▆▄█▁█▇▇▇█▇▅▇▇███▇▇██████▇███</td></tr><tr><td>train_loss</td><td>▂▃▅▂▃▃▃▃▂▂▂▃▂▂▄▂▃▃▂▂▄▁▅▃▁▂▃▂▂▂▂█▄▄▆▆▆▂▂▂</td></tr><tr><td>train_masked_loss</td><td>▂▃▅▂▃▃▃▃▂▂▂▃▂▂▄▂▃▃▂▂▄▁▅▃▁▂▃▂▂▂▂█▄▄▆▆▆▂▂▂</td></tr><tr><td>trainer/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>val_loss</td><td>█▅▄▄▄▆▃▄▃▄█▂▅▆▃█▂▃▃▃▃▄▄▃▄▃▂▁▄▂▃▂▂▂▃▂▄▂▃▃</td></tr><tr><td>val_masked_loss</td><td>█▅▄▄▄▆▃▄▃▄█▂▅▆▃█▂▃▃▃▃▄▄▃▄▃▂▁▄▂▃▂▂▂▃▂▄▂▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>49</td></tr><tr><td>masked_mse</td><td>0.00151</td></tr><tr><td>masked_pearson</td><td>0.25826</td></tr><tr><td>masked_r2</td><td>0.06607</td></tr><tr><td>train_loss</td><td>0.00133</td></tr><tr><td>train_masked_loss</td><td>0.00133</td></tr><tr><td>trainer/global_step</td><td>12799</td></tr><tr><td>val_loss</td><td>0.00151</td></tr><tr><td>val_masked_loss</td><td>0.00151</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pretrain_pbmc_from_pretrain_no_lora</strong> at: <a href='https://wandb.ai/get-v3/pretrain_pbmc/runs/od1xfypw' target="_blank">https://wandb.ai/get-v3/pretrain_pbmc/runs/od1xfypw</a><br/>Synced 6 W&B file(s), 51 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>/home/xf2217/output/pretrain_pbmc/pretrain_pbmc_from_pretrain_no_lora/wandb/run-20250104_010514-od1xfypw/logs</code>
# {'train_masked_loss': tensor(0.0013),
#  'train_loss': tensor(0.0013),
#  'val_masked_loss': tensor(0.0015),
#  'masked_pearson': tensor(0.2583),
#  'masked_mse': tensor(0.0015),
#  'masked_r2': tensor(0.0661),
#  'val_loss': tensor(0.0015)}
